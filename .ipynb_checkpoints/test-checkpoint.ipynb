# %%
# %%time
print(sum(range(1, 10)))
# Out:
# 45
# Wall time: 998 µs

# %%
def f(x,y):
    return x + y

# %%
f(3, 6)
# Out:
# 9

# %%
f?

# %%
f??

# %%
import random

random.randint(1,10)
# Out:
# 6

# %% [markdown]
# ## 이미지를 업로드 합니다!
#
# ![wordcloud.jpg](attachment:wordcloud.jpg)
